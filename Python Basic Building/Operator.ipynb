# %%
44+85
# Out:
# 129

# %%
58-54
# Out:
# 4

# %%
58*2
# Out:
# 116

# %%
65/5
# Out:
# 13.0

# %%
25%5
# Out:
# 0

# %%
5//4
# Out:
# 1

# %%
5**3
# Out:
# 125

# %%
5>8
# Out:
# False

# %%
2<5
# Out:
# True

# %%
54==55
# Out:
# False

# %%
65==65
# Out:
# True

# %%
1!=5
# Out:
# True

# %%
1!=1
# Out:
# False

# %%
5>=3
# Out:
# True

# %%
5>=5
# Out:
# True

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
1 and 0
# Out:
# 0

# %%
not True
# Out:
# False

# %%
not 1
# Out:
# False

# %%
1 or 5
# Out:
# 1

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
10&4
# Out:
# 0

# %%
bin(10)
# Out:
# '0b1010'

# %%
bin(4)
# Out:
# '0b100'

# %% [markdown]
# bin(10) bin(4)
#      &
# 1          0  - 0
# 0          1  - 0
# 1          0  - 0
# 0          0  - 0

# %%
11 | 6
# Out:
# 15

# %%
~20
# Out:
# -21

# %%
a=8
a>>2
# Out:
# 2

# %%
a= 14
a+= 5
a
# Out:
# 19
