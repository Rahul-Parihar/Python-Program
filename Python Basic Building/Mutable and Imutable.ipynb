# %%
L=[1,5,6,"Rahul",(11+64j),True, 45.845]
type(L)
L[4]
L[-4]
L[2]=600
L
# Out:
# [1, 5, 600, 'Rahul', (11+64j), True, 45.845]

# %%
N="Rahul"
N[0]
N[4]
# Out:
# 'l'

# %%
N[1]="R"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b816f41f090f> in <cell line: 1>()
# ----> 1 N[1]="R"
#
# NameError: name 'N' is not defined
